# %%
import simulator
import config
import env_plotter
import importlib          
import config
import firm
sim_test = simulator.Simulator(config.simulation_params, config.grid_params, config.firm_params)
sim_test.simulate()

# %%
import simulation_stats_plotter
import density_region_plotter

importlib.reload(env_plotter)
importlib.reload(simulator)
importlib.reload(firm)
importlib.reload(simulation_stats_plotter)
importlib.reload(density_region_plotter)

density_region_plotter.plot_combine_density(sim_test)
simulation_stats_plotter.plot_combine(sim_test)
# Out:
# /Users/tarekbounassif/Desktop/git/abm_spacial_comp/density_region_plotter.py:124: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axs[1, 0].scatter(*zip(*list), c=color, edgecolors='none', alpha=0.3)
# /Users/tarekbounassif/Desktop/git/abm_spacial_comp/density_region_plotter.py:136: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axs[1, 1].scatter(*zip(*list), c=color, edgecolors='none', alpha=0.3)
# 50

# %%
import simulator
import config
import env_plotter
import importlib          
import config
import firm

simulations = []
for i in range(0, 20):
    EXP = [
        {
            'Size': 100,
            'Seed': i,
            'Dim':2,
            'Uniform':False,
            'ClusterCount':4
        },
        {
            'FirmCount': 5,
            'StartPrice': 25,
            'Seed': i,
            'PriceChanges':[-1,0,1]
        },
        {
            'MaxIters': 50,
            'WithPrice': True
        }
    ]

    sim = simulator.Simulator(EXP[2], EXP[0], EXP[1])
    sim.simulate()
    simulations.append(sim)
    print("{sim_number} : Simulations Complete".format(sim_number=i))

# %%
import simulation_stats_plotter

importlib.reload(env_plotter)
importlib.reload(simulator)
importlib.reload(firm)
importlib.reload(simulation_stats_plotter)

simulation_stats_plotter.plot_distance_trends(simulations)

# %%
import simulator
import config
import env_plotter
import importlib          
import config
import firm

simulations = []
for i in range(0, 20):
    EXP = [
        {
            'Size': 100,
            'Seed': i,
            'Dim':2,
            'Uniform':False,
            'ClusterCount':4
        },
        {
            'FirmCount': 5,
            'StartPrice': 25,
            'Seed': i,
            'PriceChanges':[-1,0,1]
        },
        {
            'MaxIters': 50,
            'WithPrice': False
        }
    ]

    sim = simulator.Simulator(EXP[2], EXP[0], EXP[1])
    sim.simulate()
    simulations.append(sim)
    print("{sim_number} : Simulations Complete".format(sim_number=i))

# %%
import simulation_stats_plotter

importlib.reload(env_plotter)
importlib.reload(simulator)
importlib.reload(firm)
importlib.reload(simulation_stats_plotter)

simulation_stats_plotter.plot_distance_trends(simulations)

# %%
import simulator
import config
import env_plotter
import importlib
import config
import firm
sim_test = simulator.Simulator(config.simulation_params, config.grid_params, config.firm_params)
sim_test.simulate()
# Out:
# /Users/tarekbounassif/Desktop/git/abm_spacial_comp/env_plotter.py:80: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(
# 0
# 25

# %%
importlib.reload(env_plotter)
importlib.reload(simulator)
importlib.reload(firm)
env_plotter.desnity_map(sim_test.model_env, "exp1")

# %%
importlib.reload(env_plotter)
importlib.reload(simulator)
importlib.reload(firm)
#env_plotter.plot_price_history_only(sim_test.model_env)
#env_plotter.plot_rev_history_only(sim_test.model_env)
env_plotter.plot_combine(sim_test.model_env)

# %%
EXP_1 = [
    {
        'Size': 100,
        'Seed': 301111,
        'Dim':2,
        'Uniform':False,
        'ClusterCount':4
    },
    {
        'FirmCount': 4,
        'StartPrice': 10,
        'Seed': 301111,
        'PriceChanges':[-1,0,1]
    },
    {
        'MaxIters': 100,
        'WithPrice': True
    }
]
EXP_2 = [
    {
        'Size': 100,
        'Seed': 301111,
        'Dim':1,
        'Uniform':False,
        'ClusterCount':4
    },
    {
        'FirmCount': 4,
        'StartPrice': 10,
        'Seed': 301111,
        'PriceChanges':[-1,0,1]
    },
    {
        'MaxIters': 100,
        'WithPrice': True
    }
]

# %%
exp_1 = simulator.Simulator(EXP_1[2], EXP_1[0], EXP_1[1])
exp_2 = simulator.Simulator(EXP_2[2], EXP_2[0], EXP_2[1])
importlib.reload(env_plotter)
importlib.reload(simulator)
importlib.reload(firm)
env_plotter.plot_2d_system_2(exp_1.model_env)
env_plotter.plot_1d_system(exp_2.model_env, True)
# Out:
# /Users/tarekbounassif/Desktop/git/abm_spacial_comp/env_plotter.py:352: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
